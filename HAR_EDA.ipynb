# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = features
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)
y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3171           0.261915           -0.00535          -0.099739
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3171         -0.367955         -0.293715         -0.137882          -0.36862
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 3171         -0.323671         -0.144386         -0.339528  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 3171                     0.272373                              0.738758
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 3171                          0.914393                               0.24226
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 3171             -0.789861              0.024051              0.150542
#
#       subject  Activity  ActivityName
# 3171       16         1       WALKING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = features
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1926           0.276345          -0.018116          -0.104192
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1926         -0.995028         -0.991921         -0.995297          -0.99538
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1926         -0.991067         -0.995142          -0.93508  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1926                     0.018762                              0.406881
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1926                          0.130194                              0.410252
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1926              0.439098              -0.72743             -0.246777
#
#       subject  Activity  ActivityName
# 1926       18         6        LAYING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()
# Out:
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()
# Out:
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
# %%time
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.007s...
# [t-SNE] Computed neighbors for 7352 samples in 1.462s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.033s
# [t-SNE] Iteration 50: error = 124.8076096, gradient norm = 0.0249189 (50 iterations in 1.370s)
# [t-SNE] Iteration 100: error = 107.4863892, gradient norm = 0.0263869 (50 iterations in 0.918s)
# [t-SNE] Iteration 150: error = 101.3246231, gradient norm = 0.0179779 (50 iterations in 0.856s)
# [t-SNE] Iteration 200: error = 97.9103699, gradient norm = 0.0145633 (50 iterations in 0.806s)
# [t-SNE] Iteration 250: error = 95.5517883, gradient norm = 0.0147190 (50 iterations in 0.781s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.551788
# [t-SNE] Iteration 300: error = 4.1252337, gradient norm = 0.0015629 (50 iterations in 0.732s)
# [t-SNE] Iteration 350: error = 3.2144570, gradient norm = 0.0009986 (50 iterations in 0.716s)
# [t-SNE] Iteration 400: error = 2.7850392, gradient norm = 0.0007206 (50 iterations in 0.730s)
# [t-SNE] Iteration 450: error = 2.5211716, gradient norm = 0.0005666 (50 iterations in 0.731s)
# [t-SNE] Iteration 500: error = 2.3381553, gradient norm = 0.0004803 (50 iterations in 0.755s)
# [t-SNE] Iteration 550: error = 2.2004273, gradient norm = 0.0004151 (50 iterations in 0.806s)
# [t-SNE] Iteration 600: error = 2.0914705, gradient norm = 0.0003641 (50 iterations in 0.823s)
# [t-SNE] Iteration 650: error = 2.0016201, gradient norm = 0.0003360 (50 iterations in 0.747s)
# [t-SNE] Iteration 700: error = 1.9262047, gradient norm = 0.0003036 (50 iterations in 0.756s)
# [t-SNE] Iteration 750: error = 1.8611654, gradient norm = 0.0002766 (50 iterations in 0.742s)
# [t-SNE] Iteration 800: error = 1.8046775, gradient norm = 0.0002576 (50 iterations in 0.763s)
# [t-SNE] Iteration 850: error = 1.7547622, gradient norm = 0.0002409 (50 iterations in 0.744s)
# [t-SNE] Iteration 900: error = 1.7102487, gradient norm = 0.0002240 (50 iterations in 0.744s)
# [t-SNE] Iteration 950: error = 1.6702466, gradient norm = 0.0002122 (50 iterations in 0.759s)
# [t-SNE] Iteration 1000: error = 1.6339720, gradient norm = 0.0002006 (50 iterations in 0.808s)
# [t-SNE] KL divergence after 1000 iterations: 1.633972
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.006s...
# [t-SNE] Computed neighbors for 7352 samples in 1.496s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.043s
# [t-SNE] Iteration 50: error = 113.9839935, gradient norm = 0.0223442 (50 iterations in 1.193s)
# [t-SNE] Iteration 100: error = 97.9431915, gradient norm = 0.0155835 (50 iterations in 0.850s)
# [t-SNE] Iteration 150: error = 93.5749741, gradient norm = 0.0086393 (50 iterations in 0.826s)
# [t-SNE] Iteration 200: error = 91.2498016, gradient norm = 0.0068464 (50 iterations in 0.778s)
# [t-SNE] Iteration 250: error = 89.9941483, gradient norm = 0.0047060 (50 iterations in 0.765s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.994148
# [t-SNE] Iteration 300: error = 3.5730317, gradient norm = 0.0014629 (50 iterations in 0.754s)
# [t-SNE] Iteration 350: error = 2.8130939, gradient norm = 0.0007503 (50 iterations in 0.724s)
# [t-SNE] Iteration 400: error = 2.4344115, gradient norm = 0.0005284 (50 iterations in 0.748s)
# [t-SNE] Iteration 450: error = 2.2172041, gradient norm = 0.0004077 (50 iterations in 0.867s)
# [t-SNE] Iteration 500: error = 2.0726469, gradient norm = 0.0003338 (50 iterations in 0.745s)
# [t-SNE] Iteration 550: error = 1.9671264, gradient norm = 0.0002856 (50 iterations in 0.736s)
# [t-SNE] Iteration 600: error = 1.8861802, gradient norm = 0.0002445 (50 iterations in 0.744s)
# [t-SNE] Iteration 650: error = 1.8212613, gradient norm = 0.0002198 (50 iterations in 0.765s)
# [t-SNE] Iteration 700: error = 1.7687140, gradient norm = 0.0001996 (50 iterations in 0.735s)
# [t-SNE] Iteration 750: error = 1.7239683, gradient norm = 0.0001803 (50 iterations in 0.749s)
# [t-SNE] Iteration 800: error = 1.6852832, gradient norm = 0.0001661 (50 iterations in 0.751s)
# [t-SNE] Iteration 850: error = 1.6514406, gradient norm = 0.0001540 (50 iterations in 0.742s)
# [t-SNE] Iteration 900: error = 1.6217389, gradient norm = 0.0001425 (50 iterations in 0.740s)
# [t-SNE] Iteration 950: error = 1.5950477, gradient norm = 0.0001351 (50 iterations in 0.774s)
# [t-SNE] Iteration 1000: error = 1.5709784, gradient norm = 0.0001276 (50 iterations in 0.746s)
# [t-SNE] KL divergence after 1000 iterations: 1.570978
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.437s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.082s
# [t-SNE] Iteration 50: error = 105.2027817, gradient norm = 0.0280655 (50 iterations in 1.026s)
# [t-SNE] Iteration 100: error = 89.9139633, gradient norm = 0.0093886 (50 iterations in 0.862s)
# [t-SNE] Iteration 150: error = 87.0805817, gradient norm = 0.0047434 (50 iterations in 0.826s)
# [t-SNE] Iteration 200: error = 85.9189606, gradient norm = 0.0039648 (50 iterations in 0.789s)
# [t-SNE] Iteration 250: error = 85.2598114, gradient norm = 0.0027351 (50 iterations in 0.806s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.259811
# [t-SNE] Iteration 300: error = 3.1328268, gradient norm = 0.0013979 (50 iterations in 0.840s)
# [t-SNE] Iteration 350: error = 2.4881396, gradient norm = 0.0006466 (50 iterations in 0.843s)
# [t-SNE] Iteration 400: error = 2.1680696, gradient norm = 0.0004235 (50 iterations in 0.783s)
# [t-SNE] Iteration 450: error = 1.9836314, gradient norm = 0.0003160 (50 iterations in 0.794s)
# [t-SNE] Iteration 500: error = 1.8652352, gradient norm = 0.0002518 (50 iterations in 0.780s)
# [t-SNE] Iteration 550: error = 1.7823519, gradient norm = 0.0002099 (50 iterations in 0.802s)
# [t-SNE] Iteration 600: error = 1.7197334, gradient norm = 0.0001813 (50 iterations in 0.790s)
# [t-SNE] Iteration 650: error = 1.6706420, gradient norm = 0.0001608 (50 iterations in 0.789s)
# [t-SNE] Iteration 700: error = 1.6310096, gradient norm = 0.0001431 (50 iterations in 0.802s)
# [t-SNE] Iteration 750: error = 1.5985413, gradient norm = 0.0001303 (50 iterations in 0.829s)
# [t-SNE] Iteration 800: error = 1.5711455, gradient norm = 0.0001218 (50 iterations in 0.800s)
# [t-SNE] Iteration 850: error = 1.5478230, gradient norm = 0.0001100 (50 iterations in 0.839s)
# [t-SNE] Iteration 900: error = 1.5278206, gradient norm = 0.0001021 (50 iterations in 0.832s)
# [t-SNE] Iteration 950: error = 1.5102628, gradient norm = 0.0000962 (50 iterations in 0.794s)
# [t-SNE] Iteration 1000: error = 1.4948162, gradient norm = 0.0000908 (50 iterations in 0.792s)
# [t-SNE] KL divergence after 1000 iterations: 1.494816
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.503s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.172s
# [t-SNE] Iteration 50: error = 97.3153381, gradient norm = 0.0215302 (50 iterations in 1.114s)
# [t-SNE] Iteration 100: error = 84.2289734, gradient norm = 0.0094956 (50 iterations in 1.066s)
# [t-SNE] Iteration 150: error = 81.9341583, gradient norm = 0.0044143 (50 iterations in 1.064s)
# [t-SNE] Iteration 200: error = 81.1822357, gradient norm = 0.0025151 (50 iterations in 0.955s)
# [t-SNE] Iteration 250: error = 80.7813187, gradient norm = 0.0023929 (50 iterations in 0.920s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.781319
# [t-SNE] Iteration 300: error = 2.7058055, gradient norm = 0.0013120 (50 iterations in 0.882s)
# [t-SNE] Iteration 350: error = 2.1690645, gradient norm = 0.0005791 (50 iterations in 0.871s)
# [t-SNE] Iteration 400: error = 1.9178560, gradient norm = 0.0003481 (50 iterations in 0.866s)
# [t-SNE] Iteration 450: error = 1.7706430, gradient norm = 0.0002485 (50 iterations in 0.889s)
# [t-SNE] Iteration 500: error = 1.6760324, gradient norm = 0.0001942 (50 iterations in 0.893s)
# [t-SNE] Iteration 550: error = 1.6114639, gradient norm = 0.0001633 (50 iterations in 0.896s)
# [t-SNE] Iteration 600: error = 1.5654727, gradient norm = 0.0001359 (50 iterations in 1.038s)
# [t-SNE] Iteration 650: error = 1.5305330, gradient norm = 0.0001223 (50 iterations in 0.931s)
# [t-SNE] Iteration 700: error = 1.5033870, gradient norm = 0.0001071 (50 iterations in 0.970s)
# [t-SNE] Iteration 750: error = 1.4814335, gradient norm = 0.0000961 (50 iterations in 0.966s)
# [t-SNE] Iteration 800: error = 1.4636339, gradient norm = 0.0000915 (50 iterations in 0.940s)
# [t-SNE] Iteration 850: error = 1.4491866, gradient norm = 0.0000862 (50 iterations in 0.958s)
# [t-SNE] Iteration 900: error = 1.4373906, gradient norm = 0.0000820 (50 iterations in 0.889s)
# [t-SNE] Iteration 950: error = 1.4273534, gradient norm = 0.0000791 (50 iterations in 0.886s)
# [t-SNE] Iteration 1000: error = 1.4187980, gradient norm = 0.0000759 (50 iterations in 1.030s)
# [t-SNE] KL divergence after 1000 iterations: 1.418798
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.566s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.390s
# [t-SNE] Iteration 50: error = 87.2693481, gradient norm = 0.0076707 (50 iterations in 1.370s)
# [t-SNE] Iteration 100: error = 75.6944885, gradient norm = 0.0044131 (50 iterations in 1.293s)
# [t-SNE] Iteration 150: error = 74.7813187, gradient norm = 0.0023375 (50 iterations in 1.241s)
# [t-SNE] Iteration 200: error = 74.3499222, gradient norm = 0.0025728 (50 iterations in 1.244s)
# [t-SNE] Iteration 250: error = 74.1497040, gradient norm = 0.0012636 (50 iterations in 1.240s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.149704
# [t-SNE] Iteration 300: error = 2.1499450, gradient norm = 0.0011764 (50 iterations in 1.219s)
# [t-SNE] Iteration 350: error = 1.7523400, gradient norm = 0.0004848 (50 iterations in 1.184s)
# [t-SNE] Iteration 400: error = 1.5842645, gradient norm = 0.0002802 (50 iterations in 1.165s)
# [t-SNE] Iteration 450: error = 1.4908994, gradient norm = 0.0001887 (50 iterations in 1.187s)
# [t-SNE] Iteration 500: error = 1.4313622, gradient norm = 0.0001388 (50 iterations in 1.189s)
# [t-SNE] Iteration 550: error = 1.3904706, gradient norm = 0.0001123 (50 iterations in 1.310s)
# [t-SNE] Iteration 600: error = 1.3614762, gradient norm = 0.0000935 (50 iterations in 1.200s)
# [t-SNE] Iteration 650: error = 1.3402969, gradient norm = 0.0000803 (50 iterations in 1.188s)
# [t-SNE] Iteration 700: error = 1.3249350, gradient norm = 0.0000750 (50 iterations in 1.218s)
# [t-SNE] Iteration 750: error = 1.3136560, gradient norm = 0.0000681 (50 iterations in 1.218s)
# [t-SNE] Iteration 800: error = 1.3047109, gradient norm = 0.0000631 (50 iterations in 1.211s)
# [t-SNE] Iteration 850: error = 1.2977103, gradient norm = 0.0000602 (50 iterations in 1.214s)
# [t-SNE] Iteration 900: error = 1.2922115, gradient norm = 0.0000587 (50 iterations in 1.215s)
# [t-SNE] Iteration 950: error = 1.2877675, gradient norm = 0.0000555 (50 iterations in 1.222s)
# [t-SNE] Iteration 1000: error = 1.2837244, gradient norm = 0.0000527 (50 iterations in 1.212s)
# [t-SNE] KL divergence after 1000 iterations: 1.283724
# Done..
# Creating plot for this t-sne visualization..
# C:\Users\praty\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
# Wall time: 1min 43s
